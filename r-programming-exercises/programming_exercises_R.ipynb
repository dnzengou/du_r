# %% [markdown]
# R Code pulled from https://www.statmethods.net/advgraphs/ggplot2.html

# %% [markdown]
# ## Excerpt from Computer exercise 1: Introduction to ggplot2

# %% [markdown]
# In this exercise, we will study two datasets that are shipped with the ggplot2 package:
# * diamonds: describing the prices of more than 50,000 cut diamonds.
# * msleep: describing the sleep times of 83 mammals.

# %%
# ggplot2 examples
library(ggplot2)

# %% [markdown]
# ### 1. View the documentation for the two datasets

# %%
#?diamonds

#load(diamonds)

# %%
tail(diamonds, 4)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.72  Good      D     SI1     63.1  55    2757  5.69 5.75 3.61
# 2 0.70  Very Good D     SI1     62.8  60    2757  5.66 5.68 3.56
# 3 0.86  Premium   H     SI2     61.0  58    2757  6.15 6.12 3.74
# 4 0.75  Ideal     D     SI2     62.2  55    2757  5.83 5.87 3.64

# %%
summary(diamonds)
# Out:
#      carat               cut        color        clarity          depth
#  Min.   :0.2000   Fair     : 1610   D: 6775   SI1    :13065   Min.   :43.00
#  1st Qu.:0.4000   Good     : 4906   E: 9797   VS2    :12258   1st Qu.:61.00
#  Median :0.7000   Very Good:12082   F: 9542   SI2    : 9194   Median :61.80
#  Mean   :0.7979   Premium  :13791   G:11292   VS1    : 8171   Mean   :61.75
#  3rd Qu.:1.0400   Ideal    :21551   H: 8304   VVS2   : 5066   3rd Qu.:62.50
#  Max.   :5.0100                     I: 5422   VVS1   : 3655   Max.   :79.00
#                                     J: 2808   (Other): 2531
#      table           price             x                y
#  Min.   :43.00   Min.   :  326   Min.   : 0.000   Min.   : 0.000
#  1st Qu.:56.00   1st Qu.:  950   1st Qu.: 4.710   1st Qu.: 4.720
#  Median :57.00   Median : 2401   Median : 5.700   Median : 5.710
#  Mean   :57.46   Mean   : 3933   Mean   : 5.731   Mean   : 5.735
#  3rd Qu.:59.00   3rd Qu.: 5324   3rd Qu.: 6.540   3rd Qu.: 6.540
# ...

# %%
#?msleep

# %%
head(msleep, 3)
# Out:
#   name            genus      vore  order     conservation sleep_total sleep_rem
# 1 Cheetah         Acinonyx   carni Carnivora lc           12.1         NA
# 2 Owl monkey      Aotus      omni  Primates  NA           17.0        1.8
# 3 Mountain beaver Aplodontia herbi Rodentia  nt           14.4        2.4
#   sleep_cycle awake brainwt bodywt
# 1 NA          11.9      NA  50.00
# 2 NA           7.0  0.0155   0.48
# 3 NA           9.6      NA   1.35

# %% [markdown]
# ### 2. Check the data structures: how many observations and variables are there and what type of variables (numeric, categorical, etc.) are there?

# %%
summary(msleep)
# Out:
#      name              genus               vore              order
#  Length:83          Length:83          Length:83          Length:83
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  conservation        sleep_total      sleep_rem      sleep_cycle
#  Length:83          Min.   : 1.90   Min.   :0.100   Min.   :0.1167
#  Class :character   1st Qu.: 7.85   1st Qu.:0.900   1st Qu.:0.1833
#  Mode  :character   Median :10.10   Median :1.500   Median :0.3333
#                     Mean   :10.43   Mean   :1.875   Mean   :0.4396
#                     3rd Qu.:13.75   3rd Qu.:2.400   3rd Qu.:0.5792
#                     Max.   :19.90   Max.   :6.600   Max.   :1.5000
#                                     NA's   :22      NA's   :51
#      awake          brainwt            bodywt
#  Min.   : 4.10   Min.   :0.00014   Min.   :   0.005
# ...

# %%
ggplot(diamonds, aes(carat, price)) +
geom_point()
# Out:
# plot without title

# %%
ggplot(msleep, aes(sleep_total, bodywt)) +
geom_point()
# Out:
# plot without title

# %%
install.packages("dataMaid")
library("dataMaid")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘DEoptimR’, ‘gridExtra’, ‘pander’, ‘robustbase’, ‘whoami’

# %%
makeDataReport(msleep)
# Out:
# Data report generation is finished. Please wait while your output file is being rendered.

# %%
makeDataReport(diamonds)
# Out:
# Data report generation is finished. Please wait while your output file is being rendered.

# %%
install.packages("psych")
library(psych)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘tmvnsim’, ‘mnormt’
#
#
#
# Attaching package: ‘psych’
#
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha

# %%
#describeBy(diamonds, group="carat")
describe(diamonds)
# Out:
#          vars n     mean         sd           median  trimmed      mad
# carat     1   53940    0.7979397    0.4740112    0.70    0.7349655    0.474432
# cut*      2   53940    3.9040971    1.1165999    4.00    4.0424314    1.482600
# color*    3   53940    3.5941973    1.7011048    4.00    3.5526743    1.482600
# clarity*  4   53940    4.0510197    1.6471361    4.00    3.9144651    1.482600
# depth     5   53940   61.7494049    1.4326213   61.80   61.7846079    1.037820
# table     6   53940   57.4571839    2.2344906   57.00   57.3183514    1.482600
# price     7   53940 3932.7997219 3989.4397381 2401.00 3158.9923526 2475.942000
# x         8   53940    5.7311572    1.1217607    5.70    5.6600758    1.378818
# y         9   53940    5.7345260    1.1421347    5.71    5.6627443    1.363992
# z        10   53940    3.5387338    0.7056988    3.53    3.4948834    0.845082
#          min   max      range    skew        kurtosis   se
# ...

# %%
describe(msleep)
# Out:
#               vars n  mean        sd          median     trimmed
# name*          1   83  42.0000000  24.1039416 42.0000000 42.00000000
# genus*         2   83  40.2530120  22.5176589 41.0000000 40.44776119
# vore*          3   76   2.3421053   1.1260862  2.0000000  2.30645161
# order*         4   83  11.2771084   6.1511713 15.0000000 11.53731343
# conservation*  5   54   3.7777778   1.3127340  4.0000000  3.77272727
# sleep_total    6   83  10.4337349   4.4503570 10.1000000 10.38358209
# sleep_rem      7   61   1.8754098   1.2982881  1.5000000  1.70816327
# sleep_cycle    8   32   0.4395833   0.3586801  0.3333333  0.37628205
# awake          9   83  13.5674699   4.4520852 13.9000000 13.61716418
# brainwt       10   56   0.2815814   0.9764137  0.0124000  0.06602717
# bodywt        11   83 166.1363494 786.8397316  1.6700000 20.48743284
#               mad         min       max      range       skew        kurtosis
# ...

# %% [markdown]
# ### 3. Compute summary statistics (means, median, min, max, standard deviations, counts for categorical variables). Are there any missing values?

# %% [markdown]
# ### Visualization

# %%
h <- ggplot(diamonds, aes(carat, price))

# %%
e <- ggplot(msleep, aes(sleep_total, bodywt))

# %%
h + geom_area()
# Out:
# plot without title

# %%
h + geom_line()
# Out:
# plot without title

# %%
e + geom_point()
# Out:
# plot without title

# %%
e + geom_col()
# Out:
# plot without title

# %%
e + geom_boxplot()
# Out:
# Warning message:
# “Continuous x aesthetic -- did you forget aes(group=...)?”
# plot without title

# %% [markdown]
# ### R programming exercise 2
#
# #### Time series

# %%
#install.packages(c("nlme", "plotly", "forecast", "fpp2"), dependencies = TRUE)
install.packages(c("nlme", "plotly", "fpp2"), dependencies = TRUE)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘jpeg’, ‘checkmate’, ‘sass’, ‘jquerylib’, ‘showimage’, ‘fontBitstreamVera’, ‘fontLiberation’, ‘e1071’, ‘Formula’, ‘latticeExtra’, ‘htmlTable’, ‘viridis’, ‘plyr’, ‘reshape’, ‘httpuv’, ‘xtable’, ‘sourcetools’, ‘bslib’, ‘debugme’, ‘parsedate’, ‘pingr’, ‘webdriver’, ‘fontquiver’, ‘freetypeharfbuzz’, ‘gdtools’, ‘classInt’, ‘units’, ‘sp’, ‘strucchange’, ‘sandwich’, ‘Hmisc’, ‘data.table’, ‘maps’, ‘hexbin’, ‘ggthemes’, ‘GGally’, ‘shiny’, ‘shinytest’, ‘vdiffr’, ‘Cairo’, ‘webshot’, ‘listviewer’, ‘dendextend’, ‘sf’, ‘maptools’, ‘rgeos’, ‘png’, ‘plotlyGeoAssets’, ‘palmerpenguins’, ‘expsmooth’, ‘fma’, ‘gridExtra’, ‘Mcomp’, ‘vars’
#
#
# Warning message in install.packages(c("nlme", "plotly", "fpp2"), dependencies = TRUE):
# “installation of package ‘gdtools’ had non-zero exit status”
# Warning message in install.packages(c("nlme", "plotly", "fpp2"), dependencies = TRUE):
# ...

# %%
install.packages("MASS")
install.packages('forecast', dependencies = TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘tinytex’, ‘x13binary’, ‘fracdiff’, ‘lmtest’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’, ‘forecTheta’, ‘rticles’, ‘seasonal’, ‘uroot’

# %%
library(ggplot2)
library(forecast)
library(plotly)
library(nlme)
library(fpp2)
# Out:
# Error in library(forecast): there is no package called ‘forecast’
# Traceback:
#
# 1. library(forecast)

# %% [markdown]
# In this exercise, we will study the following datasets:
# * a10: total monthly anti-diabetic drug sales in Australia 1991-2008; from fpp2.
# * gold: daily gold prices in the 1980’s; from fpp2.
# * elecdaily: daily electricity demand in Victoria, Australia in 2014; from fpp2.
# * msleep: describing the sleep times of 83 mammals; from ggplot2.
# * Oxboys: the height of a number of boys from Oxford, England, over time; from nlme.
# * writing: sales of printing paper in France, 1963-1972; from fpp2.

# %% [markdown]
# ### Trends in scatterplots

# %% [markdown]
# Before we have a look at time series data, let’s return to an example that we studied in the last computer exercise;<br>
# **the relationship between animal brain size and sleep times**:

# %% [markdown]
# ```
# ggplot(msleep, aes(brainwt, sleep_total)) +
# geom_point() +
# xlab("Brain weight (logarithmic scale)") +
# ylab("Total sleep time") +
# scale_x_log10()
# ```

# %% [markdown]
# There appears to be a decreasing trend in the plot. To aid the eye, we can add a smoothed line by adding a new geom, geom_smooth, to the figure:

# %% [markdown]
# ```
# ggplot(msleep, aes(brainwt, sleep_total)) +
# geom_point() +
# geom_smooth() +
# xlab("Brain weight (logarithmic scale)") +
# ylab("Total sleep time") +
# scale_x_log10()
# ```

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Check the documentation for geom_smooth. Starting with the plot of brain weight vs. sleep time created
# above, do the following:
# 1. Decrease the degree of smoothing for the LOESS line that was fitted to the data. Which is better in
# this case, more or less smoothing?
# 2. Fit a straight line to the data instead of a non-linear LOESS line.
# 3. Remove the confidence interval from the plot.
# 4. Change the colour of the fitted line to red

# %%
ggplot(msleep, aes(brainwt, sleep_total)) +
geom_point() + 
geom_smooth(span=0.3) +
xlab("Brain weight (log scale)") +
ylab("total sleep time") +
scale_x_log10()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message:
# “Removed 27 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %%
?geom_smooth

# %%
ggplot(msleep, aes(brainwt, sleep_total)) +
geom_point() + 
# see doc. geom_smooth to remove the confidence intervalle (grey shade)
# around smooth lines, by default TRUE
geom_smooth(span=0.3, se = FALSE) +
xlab("Brain weight (log scale)") +
ylab("total sleep time") +
scale_x_log10()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message:
# “Removed 27 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %%
## OR change the confidence level (95% default value) to lower  
ggplot(msleep, aes(brainwt, sleep_total)) +
geom_point() + 
geom_smooth(span=0.3, level = 0.4) +
xlab("Brain weight (log scale)") +
ylab("total sleep time") +
scale_x_log10()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message:
# “Removed 27 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %%
## OR change the confidence level (95% default value) to lower  
ggplot(msleep, aes(brainwt, sleep_total, colour = "red")) +
#ggplot(msleep, aes(brainwt, sleep_total, color=family)) +
geom_point() + 
geom_smooth(span=0.3, level = 0.4) +
xlab("Brain weight (log scale)") +
ylab("total sleep time") +
scale_x_log10()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message:
# “Removed 27 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## Time series plots

# %%
library(fpp2)
str(a10)
# Out:
#  Time-Series [1:204] from 1992 to 2008: 3.53 3.18 3.25 3.61 3.57 ...

# %%
# plot time series wih point
a10_df <- data.frame(time = time(a10), sales = a10)
ggplot(a10_df, aes(time, sales)) +
geom_point()
# Out:
# Don't know how to automatically pick scale for object of type ts. Defaulting to continuous.
#
# Don't know how to automatically pick scale for object of type ts. Defaulting to continuous.
# plot without title

# %%
# plot it with line instead
ggplot(a10_df, aes(time, sales)) +
geom_line()
# Out:
# Don't know how to automatically pick scale for object of type ts. Defaulting to continuous.
#
# Don't know how to automatically pick scale for object of type ts. Defaulting to continuous.
# plot without title

# %%
## same with autoplot
#library(forecast)
autoplot(a10)
# Out:
# plot without title

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Using the autoplot(a10) figure, do the following:
# 1. Add a smoothed line describing the trend in the data. Make sure that it is smooth enough not to
# capture the seasonality in the data.
# 2. Change the label of the x-axis to “Year” and the label of the y-axis to “Sales ($ million)”.
# 3. Check the documentation for the ggtitle function. What does it do? Use it with the figure.
# 4. Change the colour of the time series line to red

# %%
# 1.
autoplot(a10) +
geom_smooth(span=0.3)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# 2.
autoplot(a10) +
geom_smooth(span=0.3) +
xlab("Year") +
ylab("Sales ($ million)")
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# OR
ggplot(a10_df, aes(time, sales)) +
geom_smooth(span=0.3) +
xlab("Year") +
ylab("Sales ($ million)")
# Out:
# Don't know how to automatically pick scale for object of type ts. Defaulting to continuous.
#
# Don't know how to automatically pick scale for object of type ts. Defaulting to continuous.
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
?ggtitle

# %%
# 4.
ggplot(a10_df, aes(time, sales, colour="red")) +
geom_smooth(span=0.3) +
xlab("Year") +
ylab("Sales ($ million)")
# Out:
# Don't know how to automatically pick scale for object of type ts. Defaulting to continuous.
#
# Don't know how to automatically pick scale for object of type ts. Defaulting to continuous.
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ### Exercice 3

# %% [markdown]
# # Computer exercises 3

# %%
install.packages("plotly")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘data.table’

# %%
library(ggplot2)
library(plotly)
# Out:
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout

# %% [markdown]
# In this exercise, we will study the following datasets from the ggplot2 and nycflights13 packages:
# * diamonds: describing the prices of more than 50,000 cut diamonds; from ggplot2.
# * flights: describing information about flights to and from New York; from nycflights13.
# * msleep: describing the sleep times of 83 mammals; from ggplot2

# %% [markdown]
# ## Exploring distributions

# %% [markdown]
# ### Density plots and frequency polygons

# %% [markdown]
# We already know how to visualise the distribution of the data by dividing it into bins it and plotting a
# histogram:

# %%
ggplot(diamonds, aes(carat)) +
geom_histogram(colour = "black")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# A similar plot is created using frequency polygons, which uses lines instead of bars to display the counts in
# the bins:

# %% [markdown]
# An advantage with frequency polygons is that they can be used to compare groups, e.g. diamonds with
# different cuts, without facetting:

# %%
ggplot(diamonds, aes(carat, colour = cut)) +
geom_freqpoly()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# It is clear from this figure that there are more diamonds with ideal cuts than diamonds with fair cuts in the
# data. The polygons have roughly the same shape, except perhaps for the polygon for diamonds with fair cuts.
# In some cases we are more interested in the shape of the distribution that in the actual counts in the different
# bins. Density plots are similar to frequency polygons, but show an estimate of the density function of the
# underlying random variable. These estimates are smooth curves that are scaled so that the area below them
# is 1 (i.e. scaled to be proper density functions)

# %%
ggplot(diamonds, aes(carat, colour = cut)) +
geom_density()
# Out:
# plot without title

# %% [markdown]
# From this figure, it becomes clear that low-carat diamonds tend to have better cuts, which wasn’t obvious
# from the frequency polygons. However, the plot does not provide any information about how common
# different cuts are.

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Using the density plot created above and the documentation for geom_density, do the following:
# 1. Increase the smoothness of the density curves.
# 2. Fill the area under the density curves with the same colour as the curves themselves.
# 3. Make the colours that fill the areas under the curves transparent.
# 4. The figure still isn’t that easy to interpret. Load the ggridges package, which is an extension of
# ggplot2 that allows you to make so-called ridge plots (density plots that are separated along the y-axis,
# similar to facetting). Read the documentation for geom_density_ridges and use it to make a ridge
# plot of diamond prices for different cuts.

# %% [markdown]
# ### 1.
# Note. [source](https://ggplot2.tidyverse.org/reference/geom_density.html)
#
# ```
# geom_density(
#   mapping = NULL,
#   data = NULL,
#   stat = "density",
#   position = "identity",
#   ...,
#   na.rm = FALSE,
#   orientation = NA,
#   show.legend = NA,
#   inherit.aes = TRUE,
#   outline.type = "upper"
# )
#
# stat_density(
#   mapping = NULL,
#   data = NULL,
#   geom = "area",
#   position = "stack",
#   ...,
#   bw = "nrd0",
#   adjust = 1,
#   kernel = "gaussian",
#   n = 512,
#   trim = FALSE,
#   na.rm = FALSE,
#   orientation = NA,
#   show.legend = NA,
#   inherit.aes = TRUE
# )
# ```

# %%
## bw: The smoothing bandwidth to be used. If numeric, the standard deviation 
# of the smoothing kernel. If character, a rule to choose the bandwidth, as listed in stats::bw.nrd().

ggplot(diamonds, aes(carat, colour = cut)) +
geom_density(bw="nrd0")
# Out:
# plot without title

# %% [markdown]
# ### Exercise 2

# %%
 ggplot(diamonds, aes(carat)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# **Asking questions**<br>
# Exercise 2 causes us to ask why diamonds with carat values that are multiples of 0.25 are more common that
# others. Perhaps price is involved? Unfortunately, a plot of carat versus price is not that informative:

# %%
ggplot(diamonds, aes(carat, price)) +
geom_point()
# Out:
# plot without title

# %% [markdown]
# Another option is to compute the average price in each bin of the histogram. In order to do so, we must
# extract the bin breaks from the plot object. This is beyond the standard use of ggplot21. The bins are
# extracted using ggplot_build(myPlot)$data[[1]], x), where ggplot_build is an internal function in the
# ggplot2 package that is part of creating a plot. Finally, we make use of the dplyr package to compute the
# mean in each bin.

# %%
library(dplyr)
# Create the histogram and save it as a variable
myPlot <- ggplot(diamonds, aes(carat)) +
geom_histogram(binwidth = 0.01) +
xlim(0, 3)
# A function for computing the mean price in a bin
mean_bin_func <- function(df) {
filter(diamonds, carat > df$xmin & carat <= df$xmax) %>%
summarise(mean_price = mean(price), ct = df$count[1]) %>%
mutate(mean_price = ifelse(is.nan(mean_price), NA, mean_price))
}
# Extract the bin breaks using ggplot_build, then compute the means
bin_means <- group_by(ggplot_build(myPlot)$data[[1]], x) %>%
do(mean_bin_func(.)) %>%
ungroup()
# Plot the mean prices as a scatterplot
# Add vertical lines at some multiples of 0.25 to aid the eye
ggplot(bin_means, aes(x, mean_price)) +
geom_point() +
xlab("Carat") +
ylab("Mean price") +
geom_vline(xintercept = 0.5) + geom_vline(xintercept = 0.75) +
geom_vline(xintercept = 1) + geom_vline(xintercept = 1.25) +
geom_vline(xintercept = 1.5) + geom_vline(xintercept = 1.75)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “Removed 32 rows containing non-finite values (stat_bin).”
# Warning message:
# “Removed 46 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# It appears that there are small jumps in the prices at at least some of the 0.25-marks. This explains why
# there are more diamonds just above these marks than just below.
# The above example illustrates two important things regarding exploratory data analysis:
# • Plots (in our case, the histogram) often lead to new questions.
# • A lot of the time we must manipulate (transform, summarise, etc.) our data to answer a question.
# Sometimes this is straightforward and sometimes it mean diving deep into R code. If you are unsure
# about how to do something, do a web search.

# %% [markdown]
# ### Violin plots

# %% [markdown]
# Density curves can also be used as alternatives to boxplots. In computer exercise 1, you created boxplots to
# visualise price differences between diamonds of different cuts:

# %%
ggplot(diamonds, aes(cut, price)) +
geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# Instead of using a boxplot, we can use a violin plot. Each group is represented by a “violin”, given by a
# rotated and duplicated density plot:

# %%
ggplot(diamonds, aes(cut, price)) +
geom_violin()
# Out:
# plot without title

# %% [markdown]
# Compared to boxplots, violin plots capture the entire distribution of the data rather than just a few numerical
# summaries. If you like numerical summaries (and you should!) you can add the median and the quartiles
# (corresponding to the borders of the box in the boxplot) using the draw_quantiles argument:

# %%
ggplot(diamonds, aes(cut, price)) +
geom_violin(draw_quantiles = c(0.25, 0.5, 0.75))
# Out:
# plot without title

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# Using the first boxplot create above, i.e. ggplot(diamonds, aes(cut, price)) + geom_violin(), do the
# following:
# 1. Add some colour to the plot by giving different colours to each violin.
# 2. Because the categories are shown along the x-axis, we don’t really need the legend. Add
# theme(legend.position="none") to the plot to remove the legend.
# 3. Both boxplots and violin plots are useful. Maybe we can have the best of both worlds? Add the
# corresponding boxplot inside each violin. Hint: the width and alpha arguments in geom_boxplot are
# useful for creating a nice-looking figure here.
# 4. Flip the coordinate system to create horizontal violins and boxes instead.

# %% [markdown]
# [violin source](https://www.tutorialgateway.org/r-ggplot2-violin-plot/)

# %%
#1.
ggplot(diamonds, aes(cut, price, fill = cut)) +
geom_violin(draw_quantiles = c(0.25, 0.5, 0.75))
# Out:
# plot without title

# %%
#2. 
ggplot(diamonds, aes(cut, price, fill = cut)) +
geom_violin(draw_quantiles = c(0.25, 0.5, 0.75)) +
theme(legend.position="none")
# Out:
# plot without title

# %%
#3.  
ggplot(diamonds, aes(cut, price, fill = cut)) +
geom_violin(draw_quantiles = c(0.25, 0.5, 0.75)) +
theme(legend.position="none") +
geom_boxplot(width = 0.4, alpha = 0.1)
# Out:
# plot without title

# %%
#4. 
ggplot(diamonds, aes(cut, price, fill = cut)) +
geom_violin(draw_quantiles = c(0.25, 0.5, 0.75)) +
theme(legend.position="none") +
geom_boxplot(width = 0.4, alpha = 0.1) +
coord_flip()
# Out:
# plot without title

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# ### Outliers and missing data

# %% [markdown]
# **Detecting outliers**<br>
# Both boxplots and scatterplots are useful for detecting deviating observations - often called outliers. Outliers
# can be caused by measurement errors or errors in the data input, but can also be interesting rare cases that
# can provide valuable insights about the process that generated the data. Either way, it is often of interest to
# detect outliers, for instance because that may influence the choice of what statistical tests to use.
# Let’s return to the scatterplot of diamond carat versus price:

# %%
# Let’s return to the scatterplot of diamond carat versus price:
ggplot(diamonds, aes(carat, price)) +
geom_point()
# Out:
# plot without title

# %% [markdown]
# There are some outliers which we may want to study further. For instance, there is a surprisingly cheap 5
# carat diamond, and some cheap 3 carat diamonds. But how can we identify those points?<br></br>
# One option is to use plotly to make an interactive version of the plot, where we can hover interesting points
# to see more information about them:

# %%
# Import the necessaries libraries for plotly
install.packages("IRdisplay")
library(IRdisplay)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#library(plotly)
myPlot <- ggplot(diamonds, aes(carat, price)) +
geom_point()
p1 <- ggplotly(myPlot)

# %%
htmlwidgets::saveWidget(p1, "p1.html")
display_html('')

# %% [markdown]
# ## Exercice 5

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# Create a version of the diamonds dataset where the x value is missing for all diamonds with x > 9. Make a
# scatterplot of carat versus price, with points where the x value is missing plotted in a different colour. How
# would you interpret this plot?

# %%
dat <-  diamonds %>% mutate(x = replace(x, x>9, NA))

# %%
tail(dat, 3)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.70  Very Good D     SI1     62.8  60    2757  5.66 5.68 3.56
# 2 0.86  Premium   H     SI2     61.0  58    2757  6.15 6.12 3.74
# 3 0.75  Ideal     D     SI2     62.2  55    2757  5.83 5.87 3.64

# %% [markdown]
# ### Exploration

# %%
install.packages("nycflights13")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("dplyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(nycflights13)
library(dplyr)

flights2 <- filter(flights, month == 1 & day == 1)

# %%
class(flights)
# Out:
# [1] "tbl_df"     "tbl"        "data.frame"

# %%
dim(flights)
# Out:
# [1] 336776     19

# %%
summary(flights)
# Out:
#       year          month             day           dep_time    sched_dep_time
#  Min.   :2013   Min.   : 1.000   Min.   : 1.00   Min.   :   1   Min.   : 106
#  1st Qu.:2013   1st Qu.: 4.000   1st Qu.: 8.00   1st Qu.: 907   1st Qu.: 906
#  Median :2013   Median : 7.000   Median :16.00   Median :1401   Median :1359
#  Mean   :2013   Mean   : 6.549   Mean   :15.71   Mean   :1349   Mean   :1344
#  3rd Qu.:2013   3rd Qu.:10.000   3rd Qu.:23.00   3rd Qu.:1744   3rd Qu.:1729
#  Max.   :2013   Max.   :12.000   Max.   :31.00   Max.   :2400   Max.   :2359
#                                                  NA's   :8255
#    dep_delay          arr_time    sched_arr_time   arr_delay
#  Min.   : -43.00   Min.   :   1   Min.   :   1   Min.   : -86.000
#  1st Qu.:  -5.00   1st Qu.:1104   1st Qu.:1124   1st Qu.: -17.000
#  Median :  -2.00   Median :1535   Median :1556   Median :  -5.000
#  Mean   :  12.64   Mean   :1502   Mean   :1536   Mean   :   6.895
# ...

# %%
head(flights, 4)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00

# %%
#
ggplot(flights, aes(carrier, arr_delay, fill = air_time)) +
geom_violin(draw_quantiles = c(0.25, 0.5, 0.75)) +
theme(legend.position="none") +
geom_boxplot(width = 0.4, alpha = 0.1) +
coord_flip()
# Out:
# Warning message:
# “Removed 9430 rows containing non-finite values (stat_ydensity).”
# Warning message:
# “Removed 9430 rows containing non-finite values (stat_boxplot).”
# Warning message in regularize.values(x, y, ties, missing(ties), na.rm = na.rm):
# “collapsing to unique 'x' values”
# Warning message in regularize.values(x, y, ties, missing(ties), na.rm = na.rm):
# “collapsing to unique 'x' values”
# Warning message in regularize.values(x, y, ties, missing(ties), na.rm = na.rm):
# “collapsing to unique 'x' values”
# Warning message in regularize.values(x, y, ties, missing(ties), na.rm = na.rm):
# “collapsing to unique 'x' values”
# Warning message in regularize.values(x, y, ties, missing(ties), na.rm = na.rm):
# “collapsing to unique 'x' values”
# Warning message in regularize.values(x, y, ties, missing(ties), na.rm = na.rm):
# “collapsing to unique 'x' values”
# Warning message in regularize.values(x, y, ties, missing(ties), na.rm = na.rm):
# “collapsing to unique 'x' values”
# ...

# %% [markdown]
# [filter with dplyr - source](https://blog.exploratory.io/filter-data-with-dplyr-76cf5f1a258e)
